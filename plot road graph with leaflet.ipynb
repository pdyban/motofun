# %%
query = """(way(161468888);way(47081339););
(._;>;);
out;"""

# %%
query = """way["highway"~"primary|secondary|tertiary|residential"](50.394184,10.974431,50.544216,11.24176);
(._;>;);
out;"""

# %%
query = """way["highway"~"primary|secondary|tertiary|residential"](49.5179788,10.894532,49.9179788,11.2194532);
(._;>;);
out;"""

# %%
from roadcollector import *

# %%
roads = QueryRoadCollector().get_roads(query)

# %%
# %matplotlib inline

# %%
from roadclassifier import *

# %%
clf = RoadTypeClassifier()
classified = clf.apply(roads)

# %%
from utilities import draw_road_graph
draw_road_graph(classified, draw_nodes=False)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>
